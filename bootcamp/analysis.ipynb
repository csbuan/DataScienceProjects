# %%
# disregard unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/csbuan/DataScienceProjects/main/bootcamp/YYH%20Co_Dataset.csv')
df.head(3)
# Out:
#                 Start Date/Time                 End Date/Time            Id  \
# 0  11/14/2020 4:00:00 PM +08:00  11/15/2020 4:00:00 PM +08:00  149795132607
# 1    4/2/2021 3:00:00 PM +08:00    4/3/2021 3:00:00 PM +08:00  149795132607
# 2   5/10/2020 3:00:00 PM +08:00   5/11/2020 3:00:00 PM +08:00  149795132607
#
#       Name  Stories  Total Impressions  Unique Impressions  Paid Impressions  \
# 0  YYH Co.      210               4907                3764                 0
# 1  YYH Co.       98               3657                2405                 0
# 2  YYH Co.      108               5573                2993                 0
#
#    Unique Paid Impressions  Organic Impressions  ...  Engaged Users  \
# 0                        0                 4837  ...            233
# 1                        0                 3598  ...            156
# 2                        0                 5493  ...            129
#
#    Total Consumptions  Unique Consumptions  Total Likes  Page Actions  \
# ...

# %%
df.shape
# Out:
# (501, 22)

# %%
df.columns
# Out:
# Index(['Start Date/Time', 'End Date/Time', 'Id', 'Name', 'Stories',
#        'Total Impressions', 'Unique Impressions', 'Paid Impressions',
#        'Unique Paid Impressions', 'Organic Impressions',
#        'Unique Organic Impressions', 'Engagements', 'Engaged Users',
#        'Total Consumptions', 'Unique Consumptions', 'Total Likes',
#        'Page Actions', 'Page Views', 'Video Views', 'Paid Video Views',
#        'Organic Video View', 'New Fans'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Start Date/Time               0
# End Date/Time                 0
# Id                            0
# Name                          0
# Stories                       0
# Total Impressions             0
# Unique Impressions            0
# Paid Impressions              0
# Unique Paid Impressions       0
# Organic Impressions           0
# Unique Organic Impressions    0
# Engagements                   0
# Engaged Users                 0
# Total Consumptions            0
# Unique Consumptions           0
# Total Likes                   0
# Page Actions                  0
# Page Views                    0
# Video Views                   0
# Paid Video Views              0
# Organic Video View            0
# New Fans                      0
# dtype: int64

# %%
df.notna().sum()
# Out:
# Start Date/Time               501
# End Date/Time                 501
# Id                            501
# Name                          501
# Stories                       501
# Total Impressions             501
# Unique Impressions            501
# Paid Impressions              501
# Unique Paid Impressions       501
# Organic Impressions           501
# Unique Organic Impressions    501
# Engagements                   501
# Engaged Users                 501
# Total Consumptions            501
# Unique Consumptions           501
# Total Likes                   501
# Page Actions                  501
# Page Views                    501
# Video Views                   501
# Paid Video Views              501
# Organic Video View            501
# New Fans                      501
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Start Date/Time             501 non-null    object
#  1   End Date/Time               501 non-null    object
#  2   Id                          501 non-null    int64
#  3   Name                        501 non-null    object
#  4   Stories                     501 non-null    int64
#  5   Total Impressions           501 non-null    int64
#  6   Unique Impressions          501 non-null    int64
#  7   Paid Impressions            501 non-null    int64
#  8   Unique Paid Impressions     501 non-null    int64
#  9   Organic Impressions         501 non-null    int64
#  10  Unique Organic Impressions  501 non-null    int64
#  11  Engagements                 501 non-null    int64
#  12  Engaged Users               501 non-null    int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                  Id      Stories  Total Impressions  Unique Impressions  \
# count  5.010000e+02   501.000000         501.000000          501.000000
# mean   1.497951e+11   176.822355        5607.257485         3453.536926
# std    0.000000e+00   264.712596        3987.599104         2570.467255
# min    1.497951e+11     9.000000         382.000000          201.000000
# 25%    1.497951e+11    67.000000        3128.000000         2071.000000
# 50%    1.497951e+11   104.000000        4521.000000         2765.000000
# 75%    1.497951e+11   153.000000        6940.000000         4017.000000
# max    1.497951e+11  2689.000000       29420.000000        24348.000000
#
#        Paid Impressions  Unique Paid Impressions  Organic Impressions  \
# count        501.000000               501.000000           501.000000
# mean         465.738523               374.898204          5045.201597
# std         1947.867116              1609.231844          3505.516154
# ...

# %% [markdown]
# EDA

# %%
sns.pairplot(df)

# %%
# # DO NOT RUN AGAIN
# df_cat = df['Start Date/Time', 'End Date/Time', 'Name']
# df_num = df.drop(['Start Date/Time', 'End Date/Time', 'Name'])
# df_model = df_num

# %%
df_num = df[['Stories', 'Total Impressions', 'Unique Impressions', 'Paid Impressions',
       'Unique Paid Impressions', 'Organic Impressions',
       'Unique Organic Impressions', 'Engagements', 'Engaged Users',
       'Total Consumptions', 'Unique Consumptions', 'Total Likes',
       'Page Actions', 'Page Views', 'Video Views', 'Paid Video Views',
       'Organic Video View', 'New Fans']]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_num is your DataFrame
heatmap_data = df_num.corr()

# Set the size of the heatmap
fig, ax = plt.subplots(figsize=(16, 8))

# Plot the heatmap
plot = sns.heatmap(heatmap_data, annot=True, ax=ax)

# Show the plot
plot.set_title("Facebook Metrics")
plt.show()

# %%
# Extract date and time
import pandas as pd
from datetime import datetime

# Define a function to extract the date and time from a given string
def extract_date_time(date_string):
    date_object = datetime.strptime(date_string, "%m/%d/%Y %I:%M:%S %p %z")
    return date_object.date(), date_object.time()

# Apply the function to the entire 'Start Date/Time' column
df[['Date', 'Time']] = df['Start Date/Time'].apply(extract_date_time).apply(lambda x: pd.Series(x, index=['Date', 'Time']))

# Display the modified DataFrame
df.head(3)
# Out:
#                 Start Date/Time                 End Date/Time            Id  \
# 0  11/14/2020 4:00:00 PM +08:00  11/15/2020 4:00:00 PM +08:00  149795132607
# 1    4/2/2021 3:00:00 PM +08:00    4/3/2021 3:00:00 PM +08:00  149795132607
# 2   5/10/2020 3:00:00 PM +08:00   5/11/2020 3:00:00 PM +08:00  149795132607
#
#       Name  Stories  Total Impressions  Unique Impressions  Paid Impressions  \
# 0  YYH Co.      210               4907                3764                 0
# 1  YYH Co.       98               3657                2405                 0
# 2  YYH Co.      108               5573                2993                 0
#
#    Unique Paid Impressions  Organic Impressions  ...  Unique Consumptions  \
# 0                        0                 4837  ...                   87
# 1                        0                 3598  ...                  101
# 2                        0                 5493  ...                   58
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Start Date/Time             501 non-null    object
#  1   End Date/Time               501 non-null    object
#  2   Id                          501 non-null    int64
#  3   Name                        501 non-null    object
#  4   Stories                     501 non-null    int64
#  5   Total Impressions           501 non-null    int64
#  6   Unique Impressions          501 non-null    int64
#  7   Paid Impressions            501 non-null    int64
#  8   Unique Paid Impressions     501 non-null    int64
#  9   Organic Impressions         501 non-null    int64
#  10  Unique Organic Impressions  501 non-null    int64
#  11  Engagements                 501 non-null    int64
#  12  Engaged Users               501 non-null    int64
# ...

# %%
# Convert 'Date' column to datetime format to extract the month from the date
from datetime import datetime, timedelta
df['revised_date'] = pd.to_datetime(df['Date'])

# Replace the original 'date' column with the 'revised_date' column
df['Date'] = df['revised_date']

df = df.drop(columns=['revised_date'])

# %%
df.head(5)
# Out:
#                 Start Date/Time                 End Date/Time            Id  \
# 0  11/14/2020 4:00:00 PM +08:00  11/15/2020 4:00:00 PM +08:00  149795132607
# 1    4/2/2021 3:00:00 PM +08:00    4/3/2021 3:00:00 PM +08:00  149795132607
# 2   5/10/2020 3:00:00 PM +08:00   5/11/2020 3:00:00 PM +08:00  149795132607
# 3   5/13/2020 3:00:00 PM +08:00   5/14/2020 3:00:00 PM +08:00  149795132607
# 4   7/29/2020 3:00:00 PM +08:00   7/30/2020 3:00:00 PM +08:00  149795132607
#
#       Name  Stories  Total Impressions  Unique Impressions  Paid Impressions  \
# 0  YYH Co.      210               4907                3764                 0
# 1  YYH Co.       98               3657                2405                 0
# 2  YYH Co.      108               5573                2993                 0
# 3  YYH Co.       73               2717                1935                 0
# 4  YYH Co.       62               3073                2074                 0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Start Date/Time             501 non-null    object
#  1   End Date/Time               501 non-null    object
#  2   Id                          501 non-null    int64
#  3   Name                        501 non-null    object
#  4   Stories                     501 non-null    int64
#  5   Total Impressions           501 non-null    int64
#  6   Unique Impressions          501 non-null    int64
#  7   Paid Impressions            501 non-null    int64
#  8   Unique Paid Impressions     501 non-null    int64
#  9   Organic Impressions         501 non-null    int64
#  10  Unique Organic Impressions  501 non-null    int64
#  11  Engagements                 501 non-null    int64
#  12  Engaged Users               501 non-null    int64
# ...

# %%
# Extract month and year from date column
import calendar

df['Month'] = df['Date'].dt.month.apply(lambda x: calendar.month_name[x])
df['Year'] = df['Date'].dt.year

# %%
df.head(5)
# Out:
#                 Start Date/Time                 End Date/Time            Id  \
# 0  11/14/2020 4:00:00 PM +08:00  11/15/2020 4:00:00 PM +08:00  149795132607
# 1    4/2/2021 3:00:00 PM +08:00    4/3/2021 3:00:00 PM +08:00  149795132607
# 2   5/10/2020 3:00:00 PM +08:00   5/11/2020 3:00:00 PM +08:00  149795132607
# 3   5/13/2020 3:00:00 PM +08:00   5/14/2020 3:00:00 PM +08:00  149795132607
# 4   7/29/2020 3:00:00 PM +08:00   7/30/2020 3:00:00 PM +08:00  149795132607
#
#       Name  Stories  Total Impressions  Unique Impressions  Paid Impressions  \
# 0  YYH Co.      210               4907                3764                 0
# 1  YYH Co.       98               3657                2405                 0
# 2  YYH Co.      108               5573                2993                 0
# 3  YYH Co.       73               2717                1935                 0
# 4  YYH Co.       62               3073                2074                 0
#
# ...

# %%
df = df.drop(df[df['Year'] == 2019].index)

# %%
df['Year'].value_counts()
# Out:
# Year
# 2020    366
# 2021    134
# Name: count, dtype: int64

# %%
df.to_csv('YYH Co_Dataset_Revised2.csv', index=False)
